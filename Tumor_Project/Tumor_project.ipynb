# %% [markdown]
# # Importing the data

# %%
import pandas as pd
T_data=pd.read_csv("Tumor_Detection.csv")
T_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
T_data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
T_data.drop("id", axis =1, inplace = True)

# %%
T_data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
 type(T_data.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# # Setting start Points

# %%
listcol = list(T_data.columns)

# %%
features_mean = listcol[1:11]
features_se =listcol[11:21]
features_worst=listcol[21:]

# %% [markdown]
# # Printing the starting the point

# %%
print(features_mean)
print("\n")
print(features_se)
print("\n")
print(features_worst)
# Out:
# ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']
#
#
# ['radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se']
#
#
# ['radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %%
T_data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
T_data["diagnosis"].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(T_data["diagnosis"], label="count")
# Out:
# <Axes: xlabel='count', ylabel='diagnosis'>

# %%
T_data.shape
# Out:
# (569, 31)

# %%
T_data.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
T_data["diagnosis"] = T_data["diagnosis"].map({'M': 1, 'B': 0})
corr = T_data.corr()
corr
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                 1.000000     0.730029      0.415185        0.742636
# radius_mean               0.730029     1.000000      0.323782        0.997855
# texture_mean              0.415185     0.323782      1.000000        0.329533
# perimeter_mean            0.742636     0.997855      0.329533        1.000000
# area_mean                 0.708984     0.987357      0.321086        0.986507
# smoothness_mean           0.358560     0.170581     -0.023389        0.207278
# compactness_mean          0.596534     0.506124      0.236702        0.556936
# concavity_mean            0.696360     0.676764      0.302418        0.716136
# concave points_mean       0.776614     0.822529      0.293464        0.850977
# symmetry_mean             0.330499     0.147741      0.071401        0.183027
# fractal_dimension_mean   -0.012838    -0.311631     -0.076437       -0.261477
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
x=T_data.drop("diagnosis",axis=1)
y=T_data['diagnosis']

# %% [markdown]
# # Tranning the Dataset

# %%
# divide the dataset into train and test set
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
X_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
print("T_data-shape", T_data.shape)
print("X_train.shape", X_train.shape)
print("x_test.shape",x_test.shape)
print("y_train.shape", y_train.shape)
print("y_test.shape", y_test.shape)
# Out:
# T_data-shape (569, 31)
# X_train.shape (398, 30)
# x_test.shape (171, 30)
# y_train.shape (398,)
# y_test.shape (171,)

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
x_test = ss.transform(x_test)
X_train
# Out:
# array([[ 0.14522382, -0.5321764 ,  0.09001189, ..., -0.57023857,
#         -0.71726027, -1.00195398],
#        [-1.27904235, -0.23463225, -1.28636132, ..., -1.39411901,
#          0.22647194, -0.28688884],
#        [ 0.72100319,  0.5461236 ,  0.74560564, ...,  1.45884533,
#          1.09809173,  0.65739968],
#        ...,
#        [-1.12664702, -0.38221415, -1.1206983 , ..., -1.22850791,
#         -0.06981608, -0.32378821],
#        [-0.43342012,  1.16263508, -0.44392957, ...,  0.04396058,
#         -0.13565786,  0.66914039],
#        [ 0.23975476, -0.50837287,  0.17346619, ..., -0.46864521,
#         -0.79721101, -1.09587965]], shape=(398, 30))

# %% [markdown]
# # Apply Random forest classifier

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
y_pred = rfc.predict(x_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9649122807017544
